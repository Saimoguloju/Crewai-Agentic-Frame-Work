# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import LLM

llm = LLM(
    model="openai/gpt-4o",
    temperature=0.1
)
llm.call("Hello")
# Out:
# 'Hello! How can I assist you today?'

# %%
from crewai import Agent, Task, Crew

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1]
)

# %%
crew = Crew(
    agents=[research_agent,writer_agent],
    tasks=[task1,task2],
    verbose=True,
)

# %%
crew.kickoff(inputs={"topic":"The future of elecctrical vehicles"})
# Out:
# ┌────────────────────────── Crew Execution Started ───────────────────────────┐
# │                                                                             │
# │  Crew Execution Started                                                     │
# │  Name: crew                                                                 │
# │  ID: 6b067a98-152f-4682-ad25-f28d2a2edbb1                                   │
# │  Tool Args:                                                                 │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# ┌───────────────────────────── 🤖 Agent Started ──────────────────────────────┐
# │                                                                             │
# │  Agent: Research Specialist                                                 │
# │                                                                             │
# │  Task: Find 3-5 interesting and recent facts about The future of            │
# │  elecctrical vehicles.                                                      │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Status: Executing Task...
# ┌─────────────────────────── ✅ Agent Final Answer ───────────────────────────┐
# │                                                                             │
# │  Agent: Research Specialist                                                 │
# │                                                                             │
# │  Final Answer:                                                              │
# │  - **Rapid Market Growth**: The global electric vehicle (EV) market is      │
# │  projected to grow significantly, with estimates suggesting that EVs could  │
# │  account for over 30% of all vehicle sales by 2030. This growth is driven   │
# │  by advancements in battery technology, increased consumer awareness, and   │
# │  supportive government policies.                                            │
# │                                                                             │
# │  - **Battery Technology Advancements**: Solid-state batteries are emerging  │
# │  as a game-changer for the EV industry. These batteries promise higher      │
# │  energy density, faster charging times, and improved safety compared to     │
# │  traditional lithium-ion batteries. Companies like Toyota and QuantumScape  │
# │  are investing heavily in this technology, aiming for commercialization in  │
# │  the next few years.                                                        │
# │                                                                             │
# │  - **Infrastructure Expansion**: The expansion of charging infrastructure   │
# │  is crucial for the widespread adoption of EVs. Governments and private     │
# │  companies are investing billions in building fast-charging networks. For   │
# │  instance, the U.S. government has announced plans to install 500,000       │
# │  public charging stations nationwide by 2030.                               │
# │                                                                             │
# │  - **Sustainability and Recycling**: As the number of EVs increases, so     │
# │  does the focus on sustainability and recycling of EV batteries. Companies  │
# │  are developing methods to recycle and reuse battery materials, reducing    │
# │  the environmental impact and reliance on raw materials like cobalt and     │
# │  lithium.                                                                   │
# │                                                                             │
# │  - **Autonomous and Connected Vehicles**: The future of EVs is closely      │
# │  linked with the development of autonomous and connected vehicle            │
# │  technologies. Electric vehicles are seen as ideal platforms for            │
# │  integrating autonomous driving features due to their advanced electronic   │
# │  systems and potential for seamless software updates.                       │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# 🚀 Crew: crew
# └── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
#     Assigned to: Research Specialist
#     Status: ✅ Completed
# ┌────────────────────────────── Task Completion ──────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: 03e72ab9-507e-4415-9358-9b6cf4a368a3                                 │
# │  Agent: Research Specialist                                                 │
# │  Tool Args:                                                                 │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# ┌───────────────────────────── 🤖 Agent Started ──────────────────────────────┐
# │                                                                             │
# │  Agent: Creative Writer                                                     │
# │                                                                             │
# │  Task: Write a 100-word blog post summary about The future of elecctrical   │
# │  vehicles using the facts from the research.                                │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Status: Executing Task...
# ┌─────────────────────────── ✅ Agent Final Answer ───────────────────────────┐
# │                                                                             │
# │  Agent: Creative Writer                                                     │
# │                                                                             │
# │  Final Answer:                                                              │
# │  The future of electric vehicles (EVs) is poised for remarkable growth,     │
# │  with projections indicating that EVs could comprise over 30% of all        │
# │  vehicle sales by 2030. This surge is fueled by advancements in battery     │
# │  technology, particularly the development of solid-state batteries, which   │
# │  offer higher energy density and faster charging. Companies like Toyota     │
# │  and QuantumScape are leading the charge in this innovation. Additionally,  │
# │  the expansion of charging infrastructure is critical, with plans for       │
# │  500,000 public charging stations in the U.S. by 2030. As EV adoption       │
# │  rises, sustainability efforts focus on recycling battery materials, while  │
# │  the integration of autonomous and connected technologies further enhances  │
# │  the EV landscape.                                                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# 🚀 Crew: crew
# ├── 📋 Task: 03e72ab9-507e-4415-9358-9b6cf4a368a3
# │   Assigned to: Research Specialist
# │   Status: ✅ Completed
# └── 📋 Task: 330a00f5-db2f-4e7e-947c-7d5308acbcea
#     Assigned to: Creative Writer
#     Status: ✅ Completed
# ┌────────────────────────────── Task Completion ──────────────────────────────┐
# │                                                                             │
# │  Task Completed                                                             │
# │  Name: 330a00f5-db2f-4e7e-947c-7d5308acbcea                                 │
# │  Agent: Creative Writer                                                     │
# │  Tool Args:                                                                 │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
#
# ┌────────────────────────────── Crew Completion ──────────────────────────────┐
# │                                                                             │
# │  Crew Execution Completed                                                   │
# │  Name: crew                                                                 │
# │  ID: 6b067a98-152f-4682-ad25-f28d2a2edbb1                                   │
# │  Tool Args:                                                                 │
# │  Final Output: The future of electric vehicles (EVs) is poised for          │
# │  remarkable growth, with projections indicating that EVs could comprise     │
# │  over 30% of all vehicle sales by 2030. This surge is fueled by             │
# │  advancements in battery technology, particularly the development of        │
# │  solid-state batteries, which offer higher energy density and faster        │
# │  charging. Companies like Toyota and QuantumScape are leading the charge    │
# │  in this innovation. Additionally, the expansion of charging                │
# │  infrastructure is critical, with plans for 500,000 public charging         │
# │  stations in the U.S. by 2030. As EV adoption rises, sustainability         │
# │  efforts focus on recycling battery materials, while the integration of     │
# │  autonomous and connected technologies further enhances the EV landscape.   │
# │                                                                             │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# CrewOutput(raw='The future of electric vehicles (EVs) is poised for remarkable growth, with projections indicating that EVs could comprise over 30% of all vehicle sales by 2030. This surge is fueled by advancements in battery technology, particularly the development of solid-state batteries, which offer higher energy density and faster charging. Companies like Toyota and QuantumScape are leading the charge in this innovation. Additionally, the expansion of charging infrastructure is critical, with plans for 500,000 public charging stations in the U.S. by 2030. As EV adoption rises, sustainability efforts focus on recycling battery materials, while the integration of autonomous and connected technologies further enhances the EV landscape.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The future of elecctrical vehicles.', name=None, expected_output='A bullet list of 3-5 facts', summary='Find 3-5 interesting and recent facts about The future of...', raw='- **Rapid Market Growth**: The global electric vehicle (EV) market is projected to grow significantly, with estimates suggesting that EVs could account for over 30% of all vehicle sales by 2030. This growth is driven by advancements in battery technology, increased consumer awareness, and supportive government policies.\n\n- **Battery Technology Advancements**: Solid-state batteries are emerging as a game-changer for the EV industry. These batteries promise higher energy density, faster charging times, and improved safety compared to traditional lithium-ion batteries. Companies like Toyota and QuantumScape are investing heavily in this technology, aiming for commercialization in the next few years.\n\n- **Infrastructure Expansion**: The expansion of charging infrastructure is crucial for the widespread adoption of EVs. Governments and private companies are investing billions in building fast-charging networks. For instance, the U.S. government has announced plans to install 500,000 public charging stations nationwide by 2030.\n\n- **Sustainability and Recycling**: As the number of EVs increases, so does the focus on sustainability and recycling of EV batteries. Companies are developing methods to recycle and reuse battery materials, reducing the environmental impact and reliance on raw materials like cobalt and lithium.\n\n- **Autonomous and Connected Vehicles**: The future of EVs is closely linked with the development of autonomous and connected vehicle technologies. Electric vehicles are seen as ideal platforms for integrating autonomous driving features due to their advanced electronic systems and potential for seamless software updates.', pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>), TaskOutput(description='Write a 100-word blog post summary about The future of elecctrical vehicles using the facts from the research.', name=None, expected_output='A blog post summary', summary='Write a 100-word blog post summary about The future of...', raw='The future of electric vehicles (EVs) is poised for remarkable growth, with projections indicating that EVs could comprise over 30% of all vehicle sales by 2030. This surge is fueled by advancements in battery technology, particularly the development of solid-state batteries, which offer higher energy density and faster charging. Companies like Toyota and QuantumScape are leading the charge in this innovation. Additionally, the expansion of charging infrastructure is critical, with plans for 500,000 public charging stations in the U.S. by 2030. As EV adoption rises, sustainability efforts focus on recycling battery materials, while the integration of autonomous and connected technologies further enhances the EV landscape.', pydantic=None, json_dict=None, agent='Creative Writer', output_format=<OutputFormat.RAW: 'raw'>)], token_usage=UsageMetrics(total_tokens=1148, prompt_tokens=692, cached_prompt_tokens=0, completion_ ...
